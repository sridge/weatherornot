# %%
import clean as clean
import forecast as forecast
import pandas as pd
import numpy as np
import pytz
import datetime
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
import importlib
importlib.reload(clean)
# Out:
# <module 'clean' from '/home/smr1020/bumper/forecast/clean.py'>

# %%
import importlib
importlib.reload(forecast)
# Out:
# <module 'forecast' from '/home/smr1020/bumper/forecast/forecast.py'>

# %%
forecast.run_forecast_sytem()
# Out:
# dropping na values, will take a couple minutes
# done
