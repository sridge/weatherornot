# %%
import clean
import glob
import pandas as pd
from tqdm import tqdm
import numpy as np

# %%
years = [2015,2016,2017,2018,2019]
window = '2H'
freq = '15min'

# %%
for year in years:
    print('-----------------------------')
    print(year)
    print('-----------------------------')
    median_speed = clean.clean_median_speed(year=year)
    df_weather = clean.clean_weather(year,window,freq)
    df_merge = clean.merge_data(df_weather,median_speed)
    df_morning,df_afternoon = clean.split_into_segments(df_merge,freq,year,save=True)
    
    df_weather['liq_prec'].plot()
    df_weather['frz_prec'].plot()
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# -----------------------------
# 2015
# -----------------------------
#  50%|█████     | 3/6 [00:01<00:01,  1.74it/s]<ipython-input-3-032045267219>:5: DtypeWarning: Columns (0,1,2,3,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   median_speed = clean.clean_median_speed(year=year)
# 100%|██████████| 6/6 [00:09<00:00,  1.51s/it]
# dropping na values, will take a couple minutes
# done
# station      0
# valid        0
# tmpf        11
# dwpf        14
# p01i         0
# sped       599
# dtype: int64
# /home/smr1020/bumper/clean.py:177: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_weather['p01i'][df_weather['p01i'] == 'T'] = 0.001
# /home/smr1020/bumper/clean.py:298: SettingWithCopyWarning:
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(dpi=300)
median_speed.interpolate(method='linear').plot(xlim=('2019-11-30','2019-12-02'),c='tab:orange',lw=3)
median_speed.plot(xlim=('2019-11-30','2019-12-02'),c='tab:blue',lw=3)
plt.grid()
plt.ylim(30,55)
# Out:
# (30.0, 55.0)
